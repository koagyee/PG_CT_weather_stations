# %%
import pandas as pd
import geopandas as gpd
import folium

# %%
df = pd.read_csv('Desktop/Artificial Intelligence/Connecticut Weather_Stations.csv')

# %%
df.head()
# Out:
#                            Station  Longitude   Latitude
# 0  Bridgeport Sikorsky Mem Airport    -73.1270    41.1640
# 1                 Bulls Bridge Dam    -73.4830    41.6500
# 2                       Burlington    -72.9700    41.7700
# 3                   Cockaponset Rs    -72.5197    41.4614
# 4                         Coventry    -72.3100    41.7700

# %%
gdf = gpd.GeoDataFrame(
    df, 
    geometry=gpd.points_from_xy(df['Longitude '], df['Latitude ']),
    crs="EPSG:4326"  # Standard WGS84 coordinate reference system
)
gdf.head()
# Out:
#                            Station  Longitude   Latitude   \
# 0  Bridgeport Sikorsky Mem Airport    -73.1270    41.1640
# 1                 Bulls Bridge Dam    -73.4830    41.6500
# 2                       Burlington    -72.9700    41.7700
# 3                   Cockaponset Rs    -72.5197    41.4614
# 4                         Coventry    -72.3100    41.7700
#
#                    geometry
# 0    POINT (-73.127 41.164)
# 1     POINT (-73.483 41.65)
# 2      POINT (-72.97 41.77)
# 3  POINT (-72.5197 41.4614)
# 4      POINT (-72.31 41.77)

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.columns
# Out:
# Index(['Station', 'Longitude ', 'Latitude ', 'geometry'], dtype='object')

# %%
# Reads state of Connecticut boundary map
CTbnd = gpd.read_file('Desktop/Artificial Intelligence/Connecticut_State_-234834534670141551/Connecticut_Line.shp')

# %%
locations = CTbnd.geometry

# %%
# Lengths of variables a, b and c are the same
a = ['Bridgeport Sikorsky Mem Airport', 'Bulls Bridge Dam', 'Burlington', 'Cockaponset Rs', 'Coventry', 'Danbury', 'Falls Village', 'Groton',
     'Hartford Brainard Fd', 'Hartford Bradley International Airport', 'Mansfield Hollow Lake', 'Middletown 4 W', 'Mount Carmel', 'New Haven',
     'Norfolk 2 Sw', 'Norwich Pub Util Plt', 'Shepaug Dam', 'Stamford 5 N', 'Storrs', 'West Thompson Lake', 'Wigwam Reservoir']
b = gdf['Longitude ']
c = gdf['Latitude ']
                
m = folium.Map(location=[c[11], b[11]],
                 zoom_start=9)

# This 'for' loop creates an interactive map with a marker at each of the 21 weather
# stations in Connecticut
for i in range(len(a)):
     folium.Marker([c[i], b[i]],
                  popup=a[i]).add_to(m)  
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_372117ae94dd259f31d72f65ff831bd8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_372117ae94dd259f31d72f65ff831bd8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_372117ae94dd259f31d72f65ff831bd8 = L.map(
#                 &quot;map_372117ae94dd259f31d72f65ff831bd8&quot;,
#                 {
#                     center: [41.55, -72.66],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ea7bae168cc0dfdf90ba1f60fbe5221 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3ea7bae168cc0dfdf90ba1f60fbe5221.addTo(map_372117ae94dd259f31d72f65ff831bd8);
#
#
#             var marker_df8198500b8e4e1e55476cb2050c9e09 = L.marker(
#                 [41.164, -73.127],
#                 {
# }
#             ).addTo(map_372117ae94dd259f31d72f65ff831bd8);
#
#
#         var popup_d63895f7e35d2baf80474e57d7413817 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56162d9f530f0438cf71ef03ad462ca1 = $(`&lt;div id=&quot;html_56162d9f530f0438cf71ef03ad462ca1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bridgeport Sikorsky Mem Airport&lt;/div&gt;`)[0];
#                 popup_d63895f7e35d2baf80474e57d7413817.setContent(html_56162d9f530f0438cf71ef03ad462ca1);
#
#
#
#         marker_df8198500b8e4e1e55476cb2050c9e09.bindPopup(popup_d63895f7e35d2baf80474e57d7413817)
#         ;
#
#
#
#
#             var marker_d85164ebdcd00826eefc96f63dab759c = L.marker(
#                 [41.65, -73.483],
#                 {
# }
#             ).addTo(map_372117ae94dd259f31d72f65ff831bd8);
#
#
#         var popup_6ce94b02588375c15968a2190e5273cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff12f0819dc97586c823ac5f37eb3d39 = $(`&lt;div id=&quot;html_ff12f0819dc97586c823ac5f37eb3d39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bulls Bridge Dam&lt;/div&gt;`)[0];
#                 popup_6ce94b02588375c15968a2190e5273cd.setContent(html_ff12f0819dc97586c823ac5f37eb3d39);
#
#
#
#         marker_d85164ebdcd00826eefc96f63dab759c.bindPopup(popup_6ce94b02588375c15968a2190e5273cd)
#         ;
#
#
#
#
#             var marker_725f3a91d62e30caacaf76099eb2e238 = L.marker(
#                 [41.77, -72.97],
#                 {
# }
#             ).addTo(map_372117ae94dd259f31d72f65ff831bd8);
#
#
#         var popup_3e6faa3ffa66a49e8bf4e01420e4f145 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc784db2bb9789f2dff0b95b86623d7a = $(`&lt;div id=&quot;html_dc784db2bb9789f2dff0b95b86623d7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Burlington&lt;/div&gt;`)[0];
#                 popup_3e6faa3ffa66a49e8bf4e01420e4f145.setContent(html_dc784db2bb9789f2dff0b95b86623d7a);
#
#
#
#         marker_725f3a91d62e30caacaf76099eb2e238.bindPopup(popup_3e6faa3ffa66a49e8bf4e01420e4f145)
#         ;
#
#
#
#
#             var marker_2b1e7b49bb393944f1d0ec4e8f0d58be = L.marker(
#                 [41.4614, -72.5197],
#                 {
# }
#             ).addTo(map_372117ae94dd259f31d72f65ff831bd8);
#
#
#         var popup_34803db12c7d17e559bca3b9617d4640 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21b75c6f052184653dd9142994ae09f7 = $(`&lt;div id=&quot;html_21b75c6f052184653dd9142994ae09f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cockaponset Rs&lt;/div&gt;`)[0];
#                 popup_34803db12c7d17e559bca3b9617d4640.setContent(html_21b75c6f052184653dd9142994ae09f7);
#
#
#
#         marker_2b1e7b49bb393944f1d0ec4e8f0d58be.bindPopup(popup_34803db12c7d17e559bca3b9617d4640)
#         ;
#
#
#
#
#             var marker_a4b3f65863f4330dece915b5e88fbcf7 = L.marker(
#                 [41.77, -72.31],
#                 {
# }
#             ).addTo(map_372117ae94dd259f31d72f65ff831bd8);
#
#
#         var popup_5da6c2568d755c7bcab8273fa28830a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9081c57f2e081e43a4470e267946d99d = $(`&lt;div id=&quot;html_9081c57f2e081e43a4470e267946d99d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coventry&lt;/div&gt;`)[0];
#                 popup_5da6c2568d755c7bcab8273fa28830a1.setContent(html_9081c57f2e081e43a4470e267946d99d);
#
#
#
#         marker_a4b3f65863f4330dece915b

# %%
print(a)
# Out:
# ['Bridgeport Sikorsky Mem Airport', 'Bulls Bridge Dam', 'Burlington', 'Cockaponset Rs', 'Coventry', 'Danbury', 'Falls Village', 'Groton', 'Hartford Brainard Fd', 'Hartford Bradley International Airport', 'Mansfield Hollow Lake', 'Middletown 4 W', 'Mount Carmel', 'New Haven', 'Norfolk 2 Sw', 'Norwich Pub Util Plt', 'Shepaug Dam', 'Stamford 5 N', 'Storrs', 'West Thompson Lake', 'Wigwam Reservoir']
